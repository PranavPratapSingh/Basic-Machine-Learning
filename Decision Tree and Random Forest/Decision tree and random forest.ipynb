# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
ds = pd.read_csv('mushrooms.csv')
dk = pd.read_csv('mushrooms.csv')
ds.info()
ds.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8124 entries, 0 to 8123
# Data columns (total 23 columns):
# class                       8124 non-null object
# cap-shape                   8124 non-null object
# cap-surface                 8124 non-null object
# cap-color                   8124 non-null object
# bruises                     8124 non-null object
# odor                        8124 non-null object
# gill-attachment             8124 non-null object
# gill-spacing                8124 non-null object
# gill-size                   8124 non-null object
# gill-color                  8124 non-null object
# stalk-shape                 8124 non-null object
# stalk-root                  8124 non-null object
# stalk-surface-above-ring    8124 non-null object
# stalk-surface-below-ring    8124 non-null object
# stalk-color-above-ring      8124 non-null object
# stalk-color-below-ring      8124 non-null object
# veil-type                   8124 non-null object
# ...

# %%
def convert_alpha_to_num(s):
    if str.isalpha(s):
        return ord(s)
        
print convert_alpha_to_num("s")
#ds.class.map(convert_alpha_to_num)
for ix in range(len(ds.columns)):
    pass
    #ds[ds.columns[ix]]=ds[ds.columns[ix]].map(convert_alpha_to_num)
for ix in range(len(ds.columns)):
    dk[dk.columns[ix]]=dk[dk.columns[ix]].map(convert_alpha_to_num)
# Out:
# 115

# %%
ds.head()
# Out:
#    class  cap-shape  cap-surface  cap-color  bruises  odor  gill-attachment  \
# 0    112        120          115        110      116   112              102
# 1    101        120          115        121      116    97              102
# 2    101         98          115        119      116   108              102
# 3    112        120          121        119      116   112              102
# 4    101        120          115        103      102   110              102
#
#    gill-spacing  gill-size  gill-color   ...     stalk-surface-below-ring  \
# 0            99        110         107   ...                          115
# 1            99         98         107   ...                          115
# 2            99         98         110   ...                          115
# 3            99        110         110   ...                          115
# 4           119         98         107   ...                          115
#
# ...

# %%
plt.figure(figsize=(10,10))
sns.heatmap(ds.corr())
ds.describe()
dk=dk.dropna()
df.describe()
# Out:
# ['odor']
#              class    cap-shape  cap-surface    cap-color      bruises  \
# count  5644.000000  5644.000000  5644.000000  5644.000000  5644.000000
# mean    105.201984   110.948264   112.376329   110.113395   109.897945
# std       5.345112     9.216910     8.489339     7.905873     6.942783
# min     101.000000    98.000000   102.000000    98.000000   102.000000
# 25%     101.000000   102.000000   102.000000   103.000000   102.000000
# 50%     101.000000   120.000000   115.000000   110.000000   116.000000
# 75%     112.000000   120.000000   121.000000   119.000000   116.000000
# max     112.000000   120.000000   121.000000   121.000000   116.000000
#
#        gill-attachment  gill-spacing    gill-size   gill-color  stalk-shape  \
# count      5644.000000   5644.000000  5644.000000  5644.000000  5644.000000
# mean        101.984054    102.628632    99.496811   110.890149   108.654146
# std           0.281941      7.708190     3.965359     5.450011     7.499080
# ...

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

# %%
DT = DecisionTreeClassifier()
ds=df
DT.fit(ds[ds.columns[1:]],ds[ds.columns[:1]])
print DT.feature_importances_
imp=[]
for ix in range(len(DT.feature_importances_)):
    if DT.feature_importances_[ix]==0.0 :
    #imp.update({ds.columns[ix+1] : DT.feature_importances_[ix]})
        imp.append(ds.columns[ix+1])
print imp

df = ds.drop(imp, axis=1)
df.head()
df = df.dropna()
# Out:
# [ 0.          0.          0.          0.04834923  0.          0.
#   0.17164865  0.          0.03624038  0.          0.01127822  0.          0.
#   0.          0.          0.          0.          0.          0.68469254
#   0.          0.04779098]
# ['cap-shape', 'cap-surface', 'cap-color', 'gill-attachment', 'gill-spacing', 'gill-color', 'stalk-root', 'stalk-surface-below-ring', 'stalk-color-above-ring', 'stalk-color-below-ring', 'veil-type', 'veil-color', 'ring-number', 'ring-type', 'population']
#              class      bruises    gill-size  stalk-shape  \
# count  5644.000000  5644.000000  5644.000000  5644.000000
# mean    105.201984   109.897945    99.496811   108.654146
# std       5.345112     6.942783     3.965359     7.499080
# min     101.000000   102.000000    98.000000   101.000000
# 25%     101.000000   102.000000    98.000000   101.000000
# 50%     101.000000   116.000000    98.000000   116.000000
# 75%     112.000000   116.000000    98.000000   116.000000
# ...

# %%
df.describe()

dk.describe()
# Out:
#              class    cap-shape  cap-surface    cap-color      bruises  \
# count  5644.000000  5644.000000  5644.000000  5644.000000  5644.000000
# mean    105.201984   110.948264   112.376329   110.113395   109.897945
# std       5.345112     9.216910     8.489339     7.905873     6.942783
# min     101.000000    98.000000   102.000000    98.000000   102.000000
# 25%     101.000000   102.000000   102.000000   103.000000   102.000000
# 50%     101.000000   120.000000   115.000000   110.000000   116.000000
# 75%     112.000000   120.000000   121.000000   119.000000   116.000000
# max     112.000000   120.000000   121.000000   121.000000   116.000000
#
#               odor  gill-attachment  gill-spacing    gill-size   gill-color  \
# count  5644.000000      5644.000000   5644.000000  5644.000000  5644.000000
# mean    106.401843       101.984054    102.628632    99.496811   110.890149
# std       4.645822         0.281941      7.708190     3.965359     5.450011
# ...

# %%
ds=ds.dropna()

# %%
X=ds[ds.columns[1:]]
Y=ds[ds.columns[:1]]
split=int(0.9*ds.shape[0])
RF=RandomForestClassifier(n_estimators=50)
RF.fit(X[:split],Y[:split])
RF.score(X[split:],Y[split:])
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:5: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   """
# 0.8371681415929203

# %%
X=dk[ds.columns[1:]]
Y=dk[ds.columns[:1]]
RF=RandomForestClassifier(n_estimators=50)
RF.fit(X[:split],Y[:split])
RF.score(X[split:],Y[split:])
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:4: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   after removing the cwd from sys.path.
# 0.92920353982300885
