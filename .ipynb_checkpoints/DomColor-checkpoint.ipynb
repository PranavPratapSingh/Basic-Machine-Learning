# %%
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline
import cv2
from sklearn.cluster import KMeans

# %%
im = cv2.imread('./image.jpg')
im = cv2.cvtColor(im, cv2.COLOR_BGR2RGB)

r, c = im.shape[:2]
out_r = 120
im = cv2.resize(im, (int(out_r*float(c)/r), out_r))
pixels = im.reshape((-1, 3))

print pixels.shape
plt.imshow(im)
# Out:
# (25680, 3)

# %%
km = KMeans(n_clusters=8)
km.fit(pixels)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=8, n_init=10, n_jobs=1, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)

# %%
colors = np.asarray(km.cluster_centers_, dtype='uint8')

# %%
per = np.asarray(np.unique(km.labels_, return_counts=True)[1], dtype='float32')
per = per / pixels.shape[0]
per
# Out:
# array([ 0.11436916,  0.06207165,  0.09205607,  0.24396418,  0.04404205,
#         0.16522586,  0.08609813,  0.1921729 ], dtype=float32)

# %%
plt.figure(0)
for ix in range(colors.shape[0]):
    patch = np.ones((20, 20, 3))
    patch[:, :, :] = 255 - colors[ix]
    plt.subplot(1, colors.shape[0], ix+1)
    plt.axis("off")
    plt.imshow(patch)

# %%
dom = [[per[ix], colors[ix]] for ix in range(km.n_clusters)]
DOM = sorted(dom, key=lambda z: z[0], reverse=True)

# %%
plt.figure(0)
plt.axis('off')

patch = np.zeros((50, 500, 3))

start = 0
for cx in range(km.n_clusters):
    width = int(DOM[cx][0] * patch.shape[1])
    end = start + width
    patch[:, start:end, :] = 255 - DOM[cx][1]
    start = end

plt.imshow(patch)
plt.show()

# %%
k=0
pixels = im.reshape((-1,5))
for ix in range(im.shape[0]):
    for jx in range(im.shape[1]):
        
        pixels[k]=[ix,jx,im[ix][jx][0],im[ix][jx][1],im[ix][jx][2]]
        k+=1
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-189-9d93d8e9ff6d> in <module>()
#       4     for jx in range(im.shape[1]):
#       5
# ----> 6         pixels[k]=[ix,jx,im[ix][jx][0],im[ix][jx][1],im[ix][jx][2]]
#       7         k+=1
#       8
#
# IndexError: index 15408 is out of bounds for axis 0 with size 15408

# %%
print pixels
print pixels.shape
print im.shape
# Out:
# [[  0   0  43  30  24]
#  [  0   1  30  24  19]
#  [  0   2   1  30  24]
#  ...,
#  [ 71 211  43  41  70]
#  [ 71 212  25 196  43]
#  [ 71 213  42  33   2]]
# (15408, 5)
# (120, 214, 3)

# %%
km = KMeans(n_clusters=8)
km.fit(pixels)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=8, n_init=10, n_jobs=1, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)

# %%
colors = np.asarray(km.cluster_centers_, dtype='uint8')

# %%
per = np.asarray(np.unique(km.labels_, return_counts=True)[1], dtype='float32')
per = per / pixels.shape[0]
per
color2=[]
for x in range(colors.shape[0]):
    color2.append(    [colors[x][2],colors[x][3],colors[x][4]])
print color2,colors
colors=np.asarray(color2)
# Out:
# [[35, 151, 25], [26, 23, 24], [26, 37, 153], [156, 23, 151], [37, 158, 29], [25, 42, 151], [160, 29, 23], [29, 27, 24]] [[ 36  52  35 151  25]
#  [ 34  51  26  23  24]
#  [ 36 161  26  37 153]
#  [ 36 108 156  23 151]
#  [ 36 160  37 158  29]
#  [ 36  51  25  42 151]
#  [ 35 102 160  29  23]
#  [ 34 161  29  27  24]]

# %%
plt.figure(0)
for ix in range(colors.shape[0]):
    patch = np.ones((20, 20, 3))
    patch[: , : , :] = 255 - colors[ix]
    plt.subplot(1, colors.shape[0], ix+1)
    plt.axis("off")
    plt.imshow(patch)

# %%
dom = [[per[ix], colors[ix]] for ix in range(km.n_clusters)]
DOM = sorted(dom, key=lambda z: z[0], reverse=True)

# %%
plt.figure(0)
plt.axis('off')

patch = np.zeros((50, 500, 3))

start = 0
for cx in range(km.n_clusters):
    width = int(DOM[cx][0] * patch.shape[1])
    end = start + width
    patch[:, start:end, :] = 255 - DOM[cx][1]
    start = end

plt.imshow(patch)
plt.show()
