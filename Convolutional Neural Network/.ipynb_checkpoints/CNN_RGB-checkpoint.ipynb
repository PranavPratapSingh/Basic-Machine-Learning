# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline

import cv2
import keras

from keras.layers import Convolution2D, Flatten, Dense, MaxPool2D, Activation, Dropout
from keras.layers import UpSampling2D 
from keras.models import Sequential
from keras.utils import np_utils
# Out:
# Using TensorFlow backend.

# %%
im=cv2.imread('/home/pranavpratapsingh/Documents/Codes/Python/Perceptron_Summer_2017old/class_04/img.jpg') 
img= cv2.cvtColor(im,cv2.COLOR_BGR2RGB)
plt.imshow(img, ) 
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
print img
# Out:
# [[[  2  51 188]
#   [  2  51 188]
#   [  2  51 188]
#   ...,
#   [  3  26 190]
#   [  3  26 190]
#   [  3  26 190]]
#
#  [[  2  51 188]
#   [  2  51 188]
#   [  3  52 189]
#   ...,
#   [  3  26 190]
#   [  3  26 190]
#   [  3  26 190]]
#
#  [[  3  52 189]
#   [  3  52 189]
#   [  3  52 189]
#   ...,
#   [  3  26 190]
#   [  3  26 190]
#   [  3  26 190]]
#
#  ...,
#  [[  2  69 176]
#   [  6  73 180]
#   [  8  75 182]
#   ...,
#   [ 18  88 157]
#   [ 22  91 160]
#   [ 14  83 152]]
#
#  [[  2  69 176]
#   [  6  73 180]
#   [  8  75 182]
#   ...,
#   [ 29  99 168]
#   [ 23  92 161]
#   [ 27  96 165]]
#
#  [[  2  69 176]
#   [  6  73 180]
#   [  8  75 182]
#   ...,
#   [ 17  87 156]
#   [  8  77 146]
#   [ 23  92 161]]]

# %%
print im.shape
r=[[0, -1, 0],
   [-1, 5, -1],
   [0, -1, 0]]
k=np.array([r,r,r])
print k.shape
# Out:
# (900, 1600, 3)
# (3, 3, 3)

# %%
out_r=img.shape[0]-k.shape[0]+1
out_c=img.shape[1]-k.shape[1]+1
X=np.zeros((out_r,out_c,3))
print X.shape
# Out:
# (898, 1598, 3)

# %%
image_patch=[]
for rx in range(out_r):
    for cx in range(out_c):
            for ix in range(3):   
                image_patch.append(img[rx:k.shape[0]+rx ,cx:k.shape[1]+cx,ix])
            prod=image_patch*k
            for ix in range(3):
                X[rx,cx,ix]=255.0-max(prod[ix].sum(),0)
            image_patch=[]

# %%
#ximg= cv2.cvtColor(X,cv2.COLOR_BGR2RGB)
plt.imshow(X)
plt.show()

# %%
X=data[:,1:]/255.0
y=np_utils.to_categorical(data[:,0])

print X.shape, y.shape
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-101-7c50c1585783> in <module>()
# ----> 1 X=data[:,1:]/255.0
#       2 y=np_utils.to_categorical(data[:,0])
#       3
#       4 print X.shape, y.shape
#
# NameError: name 'data' is not defined

# %%
split= int(0.8*X.shape[0])

X_train=X[:split].reshape((-1,28,28,1))
X_test=X[split:].reshape((-1,28,28,1))

y_train=y[:split]
y_test=y[split:]

print X_train.shape, X_test.shape
print y_train.shape, y_test.shape
# Out:
# (8000, 28, 28, 1) (2000, 28, 28, 1)
# (8000, 10) (2000, 10)
