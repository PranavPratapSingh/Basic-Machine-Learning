# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
im=cv2.imread('/home/pranavpratapsingh/Documents/Codes/Python/Perceptron_Summer_2017old/class_04/im.jpg') 
img= cv2.cvtColor(im,cv2.COLOR_BGR2GRAY)
plt.imshow(img, cmap='gray') 
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
add=3
print img[add:k.shape[0]+add ,add:k.shape[1]+add]
# Out:
# [[132 131 131]
#  [135 135 134]
#  [136 135 135]]

# %%
print img
# Out:
# [[122 123 122 ..., 146 147 149]
#  [126 126 126 ..., 147 147 148]
#  [127 128 128 ..., 148 148 148]
#  ...,
#  [136 135 124 ..., 159 159 159]
#  [133 140 138 ..., 159 159 159]
#  [120 128 148 ..., 159 159 159]]

# %%
print im.shape
k=np.array([[-1, -1, -1],
           [-1, 8 , -1],
           [-1, -1, -1]])
# Out:
# (1200, 1920, 3)

# %%
out_r=img.shape[0]-k.shape[0]+1
out_c=img.shape[1]-k.shape[1]+1
X=np.zeros((out_r,out_c))
print X.shape
# Out:
# (1198, 1918)

# %%
for rx in range(out_r):
    for cx in range(out_c):
        image_patch=img[rx:k.shape[0]+rx, cx:k.shape[1]+cx]
        prod=image_patch*k
        X[rx,cx]=prod.sum()

# %%
X_=X*(X>0)
plt.imshow(X_,cmap='gray')
plt.show()
